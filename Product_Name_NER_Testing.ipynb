# %%
import pandas as pd
import spacy
import re
import json
from collections import defaultdict

# %% [markdown]
# ### Load Testing data

# %%
test_df = pd.read_excel('/content/Product_NER_Validation.xlsx')
print("Shape of dataframe:", test_df.shape)
print(test_df.info())
test_df.head(3)
# Out:
# Shape of dataframe: (99, 1)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   99 non-null     object
# dtypes: object(1)
# memory usage: 920.0+ bytes
# None
#                                                title
# 0                          the alpha of all trimmers
# 1  irobot roomba pro intelligent floorvac robotic...
# 2          everlast classic heavyweight duffel black

# %%
import zipfile
with zipfile.ZipFile('/content/Product_Name_NER_Model.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/Product_Name_NER_Model')

# %%
# Path to your trained model
model_path = "/content/Product_Name_NER_Model"

# load model
nlp = spacy.load(model_path)

# %%
def preprocess_text(text):
    text = ' '.join(text.lower().strip().split())
    return text

# %%
results = []

for _, row in test_df.iterrows():
    title = row['title']
    processed_text = preprocess_text(title)
    doc = nlp(processed_text)

    grouped_entities = defaultdict(list)
    ner_entities = []

    for ent in doc.ents:
        grouped_entities[ent.label_].append(ent.text)
        ner_entities.append((ent.start_char, ent.end_char, ent.label_))

    results.append({
        'title': title,
        'extracted_attributes': json.dumps(dict(grouped_entities)),
        'ner_entities': str(ner_entities)
    })

submission_df = pd.DataFrame(results)

# %%
# Save to CSV
submission_df.to_csv('Product_Name_NER_Submission.csv', index=False)

# %%
submission_df.head(50)
# Out:
#                                                 title  \
# 0                           the alpha of all trimmers
# 1   irobot roomba pro intelligent floorvac robotic...
# 2           everlast classic heavyweight duffel black
# 3   activetool  airman cordless multi-purpose air ...
# 4   apple iphone 3g digitizer touch screen replace...
# 5   carolina cottage 42-inch round drop leaf table...
# 6   martex 300-thread-count queen flat sheet, heather
# 7   home decor 5202-42 easel adjustable clr.wht 3....
# 8                           sprite 1litre lemon drink
# 9   c2g 29550 2-port uxga monitor splitter/extende...
# 10             tekton 8-inch swivel bench vise | 5409
# 11  snackmasters california style beef jerky, hot ...
# 12  pfaltzgraff ocean breeze 5-piece stoneware pla...
# 13  d-link dp-311u wireless print server, 1-usb po...
# 14  bodum chambord 34-ounce polycarbonate french c...
# 15  organic valley, organic 1% low fat milk, paste...
# 16  bear naked all natural peanut butter granola, ...
# 17  murphy 10w cylindrical surface mounted cob spo...
# 18  mountain 5900 6-inch digital stainless steel c...
# 19  original and licensed ktm rc 390 bike 1:12 sca...
# 20           mikasa antique white cereal bowl, 6-inch
# 21                callebaut dark callets 70.4 %  2 lb
# 22  2-pack replacement hoover rewind 59157055 filt...
# 23                    kinley 1l drinking water bottle
# 24  graco 288420 airless four finger ftx paint spr...
# 25  professional kingston microsdhc 8gb 8 gigabyte...
# 26  west chester 2550 posishield examination grade...
# 27                   trudeau 15-piece meat fondue set
# 28  ultra pods crystal wireless earbuds, transpare...
# 29  krups 854-75 aquastyle cordless electric 10-cu...
# 30    shimano cs-hg50 9 speed cassette silver  14-25t
# 31            nautica men's multi plaid poplin shorts
# 32  celestron soft case for nexstar 60/80gt telescope
# 33                            buddha inlit lamp green
# 34  boost nutritional pudding, chocolate, 5 oz cup...
# 35          strawberry shortcake sweet window valance
# 36     norpro 5550d stainless steel my favorite scoop
# 37  premium double sided photo paper, 8 1/2 x 11, ...
# 38  fujifilm quick snap single use wedding camera ...
# 39                                  speed queen ate50
# 40  chex snack mix chocolate peanut butter, 12-oun...
# 41  le creuset enameled cast-iron 5-quart oval fre...
# 42  laselva designs  degas two ballerinas stick um...
# 43  bumble bee sardines in mustard, 3.75-ounce can...
# 44  ysn ysn401 worthington cylinders 303375 lp tan...
# 45                        24-hour gift hamper for her
# 46  autofurnish pullover window car sun shades pro...
# 47  army doo rag black motorcycle skull cap cotton...
# 48  milton s-921 single chuck head pencil tire pre...
# 49  grosgrain ribbon dippy dots 1.5 inch 20 yards ...
#
#                                  extracted_attributes  \
# 0   {"features_specifications": ["the alpha of all...
# 1   {"brand": ["irobot roomba"], "features_specifi...
# 2   {"brand": ["everlast"], "features_specificatio...
# 3   {"brand": ["activetool"], "features_specificat...
# 4   {"brand": ["apple iphone"], "features_specific...
# 5   {"brand": ["carolina cottage"], "quantity": ["...
# 6   {"brand": ["martex"], "features_specifications...
# 7   {"brand": ["home"], "features_specifications":...
# 8   {"brand": ["sprite"], "features_specifications...
# 9   {"brand": ["c2g"], "features_specifications": ...
# 10  {"brand": ["tekton"], "quantity": ["8-inch"], ...
# 11  {"brand": ["snackmasters"], "features_specific...
# 12  {"brand": ["pfaltzgraff", "ocean breeze"], "qu...
# 13  {"brand": ["d-link"], "features_specifications...
# 14  {"brand": ["bodum"], "features_specifications"...
# 15  {"brand": ["organic valley"], "features_specif...
# 16  {"brand": ["bear naked all natural peanut"], "...
# 17  {"brand": ["murphy 10w"], "features_specificat...
# 18  {"brand": ["mountain"], "features_specificatio...
# 19  {"brand": ["original"], "features_specificatio...
# 20  {"brand": ["mikasa"], "features_specifications...
# 21  {"brand": ["callebaut"], "features_specificati...
# 22  {"brand": ["2-pack replacement"], "features_sp...
# 23  {"brand": ["kinley 1l"], "features_specificati...
# 24  {"brand": ["graco 288420"], "features_specific...
# 25  {"brand": ["professional kingston microsdhc"],...
# 26  {"brand": ["west", "chester"], "features_speci...
# 27  {"brand": ["trudeau"], "quantity": ["15-piece"...
# 28  {"brand": ["ultra pods"], "color": ["crystal w...
# 29  {"brand": ["krups", "aquastyle"], "features_sp...
# 30  {"brand": ["shimano cs-hg50"], "quantity": ["9...
# 31  {"brand": ["nautica"], "gender": ["men's"], "f...
# 32  {"brand": ["celestron"], "features_specificati...
# 33                        {"brand": ["buddha inlit"]}
# 34  {"brand": ["boost"], "features_specifications"...
# 35  {"brand": ["strawberry"], "features_specificat...
# 36  {"brand": ["norpro"], "features_specifications...
# 37  {"brand": ["premium"], "features_specification...
# 38  {"brand": ["fujifilm"], "features_specificatio...
# 39        {"brand": ["speed"], "quantity": ["queen"]}
# 40  {"brand": ["chex snack"], "features_specificat...
# 41  {"brand": ["le creuset enameled"], "features_s...
# 42  {"brand": ["laselva designs degas two ballerin...
# 43  {"brand": ["bumble"], "features_specifications...
# 44  {"brand": ["ysn"], "features_specifications": ...
# 45          {"quantity": ["24-hour gift hamper for"]}
# 46  {"brand": ["autofurnish"], "features_specifica...
# 47  {"brand": ["army doo"], "features_specificatio...
# 48  {"brand": ["milton"], "features_specifications...
# 49  {"brand": ["grosgrain"], "features_specificati...
#
#                                          ner_entities
# 0                [(0, 25, 'features_specifications')]
# 1   [(0, 13, 'brand'), (18, 38, 'features_specific...
# 2   [(0, 8, 'brand'), (9, 16, 'features_specificat...
# 3   [(0, 10, 'brand'), (11, 17, 'features_specific...
# 4   [(0, 12, 'brand'), (60, 74, 'features_specific...
# 5   [(0, 16, 'brand'), (17, 24, 'quantity'), (25, ...
# 6   [(0, 6, 'brand'), (7, 10, 'features_specificat...
# 7   [(0, 4, 'brand'), (11, 24, 'features_specifica...
# 8   [(0, 6, 'brand'), (7, 13, 'features_specificat...
# 9   [(0, 3, 'brand'), (4, 9, 'features_specificati...
# 10  [(0, 6, 'brand'), (7, 13, 'quantity'), (14, 20...
# 11  [(0, 12, 'brand'), (13, 40, 'features_specific...
# 12  [(0, 11, 'brand'), (12, 24, 'brand'), (25, 32,...
# 13  [(0, 6, 'brand'), (15, 23, 'features_specifica...
# 14  [(0, 5, 'brand'), (6, 37, 'features_specificat...
# 15  [(0, 14, 'brand'), (16, 23, 'features_specific...
# 16  [(0, 29, 'brand'), (46, 59, 'quantity'), (60, ...
# 17  [(0, 10, 'brand'), (11, 42, 'features_specific...
# 18  [(0, 8, 'brand'), (9, 13, 'features_specificat...
# 19  [(0, 8, 'brand'), (26, 28, 'features_specifica...
# 20  [(0, 6, 'brand'), (7, 14, 'features_specificat...
# 21  [(0, 9, 'brand'), (10, 29, 'features_specifica...
# 22  [(0, 18, 'brand'), (42, 48, 'features_specific...
# 23  [(0, 9, 'brand'), (25, 31, 'features_specifica...
# 24  [(0, 12, 'brand'), (26, 32, 'features_specific...
# 25  [(0, 31, 'brand'), (32, 37, 'quantity'), (38, ...
# 26  [(0, 4, 'brand'), (5, 12, 'brand'), (13, 40, '...
# 27  [(0, 7, 'brand'), (8, 16, 'quantity'), (17, 32...
# 28  [(0, 10, 'brand'), (11, 27, 'color'), (37, 70,...
# 29  [(0, 5, 'brand'), (6, 9, 'features_specificati...
# 30  [(0, 15, 'brand'), (16, 23, 'quantity'), (24, ...
# 31  [(0, 7, 'brand'), (8, 13, 'gender'), (14, 32, ...
# 32  [(0, 9, 'brand'), (10, 23, 'features_specifica...
# 33                                 [(0, 12, 'brand')]
# 34  [(0, 5, 'brand'), (6, 25, 'features_specificat...
# 35  [(0, 10, 'brand'), (11, 20, 'features_specific...
# 36  [(0, 6, 'brand'), (7, 12, 'features_specificat...
# 37  [(0, 7, 'brand'), (8, 14, 'features_specificat...
# 38  [(0, 8, 'brand'), (9, 26, 'features_specificat...
# 39             [(0, 5, 'brand'), (6, 11, 'quantity')]
# 40  [(0, 10, 'brand'), (15, 24, 'features_specific...
# 41  [(0, 19, 'brand'), (20, 29, 'features_specific...
# 42                                 [(0, 51, 'brand')]
# 43  [(0, 6, 'brand'), (11, 19, 'features_specifica...
# 44  [(0, 3, 'brand'), (4, 10, 'features_specificat...
# 45                              [(0, 23, 'quantity')]
# 46  [(0, 11, 'brand'), (12, 20, 'features_specific...
# 47  [(0, 8, 'brand'), (9, 12, 'features_specificat...
# 48  [(0, 6, 'brand'), (7, 19, 'features_specificat...
# 49  [(0, 9, 'brand'), (10, 16, 'features_specifica...

# %% [markdown]
# # My observations
# 1. Model is performing good on the all the attributes except the dimensions (confusing it with the quantity)
# 2. Overall Good brand and feature specification results.
